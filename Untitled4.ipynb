# %% [markdown]
# <a href="https://colab.research.google.com/github/Asiya0528/siwes-2026/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

hh['monthly_expenditure_ngn'].describe()

# %%
hh['distance_to_school_km'].describe()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

hh['monthly_expenditure_ngn'].hist(bins=60, ax=axes[0])
axes[0].set_title('Monthly expenditure (NGN)')

hh['distance_to_school_km'].hist(bins=60, ax=axes[1])
axes[1].set_title('Distance to school (km)')

plt.tight_layout()
plt.show()

# %%
print (hh['monthly_expenditure_ngn'].value_counts().head())
print(hh['distance_to_school_km'].value_counts().head())

# %%
roster =pd.read_csv(DATA + 'nhes_roster.csv')

roster['age'].hist(bins=50)
plt.title('Age')
plt.show()

print(roster['age'].value_counts().head())
print("Mean age:", roster['age'].mean().round(1))

# %%
hh['distance_to_school_km'] = hh['distance_to_school_km'].replace(99, np.nan)
hh['monthly_expenditure_ngn'] = hh['monthly_expenditure_ngn'].replace(999999,np.nan)
roster['age'] = roster['age'].replace(99, np.nan)

print(hh['distance_to_school_km'].isna().sum(), "diatance unknown")
print(hh['monthly_expenditure_ngn'].isna().sum(),"expenditures refused")
print(roster['age'].isna().sum(). "ages unknown")

print("Mean age now:", roster['age'].mean().round(1))
