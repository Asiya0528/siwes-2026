# %% [markdown]
# <a href="https://colab.research.google.com/github/Asiya0528/siwes-2026/blob/main/day04_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 name = "Asiya"       #str - text
 age = 18             #int - whole number
 height = 1.62        #float - decimal number
 is_student = True    #bool - True or False

 print(type(name), type(age), type(height), type(is_student))
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
print(10/3)
print(10//3)
print(10 % 3)
print(10 **3)
# Out:
# 3.3333333333333335
# 3
# 1
# 1000

# %%
score = 67
if score>= 70:
    grade = "A"
elif score >= 60:
    grade = "B"
elif score >= 50:
    grade = "C"
else:
    grade = "F"

print(f"Score {score} is grade {grade}")
# Out:
# Score 67 is grade B

# %%
for i in range(1,6):
    print(i, "squared is", i ** 2)
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9
# 4 squared is 16
# 5 squared is 25

# %%
ages = [4,12,7,19,15,3,11]
school_age = 0

for a in ages:
    if 6 <= a <= 16:
      school_age = school_age + 1

print("Children of school age:", school_age)
# Out:
# Children of school age: 4
