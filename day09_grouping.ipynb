# %% [markdown]
# <a href="https://colab.research.google.com/github/Asiya0528/siwes-2026/blob/main/day09_grouping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hh.groupby('zone')['electricity'].mean()

# %%
(hh.groupby('zone')['electricity'].mean()
   .sort_values(ascending=False)
   .round(3))

# %%
hh.groupby('sector').size()

# %%
hh.groupby('zone')['monthly_expenditure_ngn'].agg(['count','mean','median'])

# %%
hh.groupby(['zone','sector'])['electricity'].mean().round(3)

# %%
pd.crosstab(hh['zone'],hh['sector'])
pd.crosstab(hh['zone'], hh['toilet_type'], normalize='index').round(3)
